# %% [markdown]
# <a href="https://colab.research.google.com/github/alfianrifqy/STKI/blob/preprocessing-nltk/Clean_Dataset_Stem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = pd.read_csv('clean_dataset.csv', sep=';')

# %%
dataset.head()
# Out:
#    Unnamed: 0  Sentiment                             Instagram Comment Text  \
# 0           0          0   <USERNAME> TOLOL!! Gak ada hubungan nya kegug...
# 1           1          0  Geblek lo tata...cowo bgt dibela2in balikan......
# 2           2          0  Kmrn termewek2 skr lengket lg duhhh kok labil ...
# 3           3          0  Intinya kalau kesel dengan ATT nya, gausah ke ...
# 4           4          0  hadewwwww permpuan itu lg!!!!sakit jiwa,knp ha...
#
#                                               step01  \
# 0  username tolol gak ada hubungan nya keguguran ...
# 1  geblek lo tata cowo bgt dibelain balikan hadew...
# 2  kmrn termewek skr lengket lg duhhh kok labil b...
# 3  intinya kalau kesel dengan att nya gausah ke a...
# 4  hadewwwww permpuan itu lg sakit jiwa knp harus...
#
#                                               tokens  \
# 0  ['username', 'tolol', 'gak', 'ada', 'hubungan'...
# 1  ['geblek', 'lo', 'tata', 'cowo', 'bgt', 'dibel...
# 2  ['kmrn', 'termewek', 'skr', 'lengket', 'lg', '...
# 3  ['intinya', 'kalau', 'kesel', 'dengan', 'att',...
# 4  ['hadewwwww', 'permpuan', 'itu', 'lg', 'sakit'...
#
#                                         final_tokens  \
# 0  ['username', 'tolol', 'gak', 'ada', 'hubungan'...
# 1  ['geblek', 'lo', 'tata', 'cowo', 'bgt', 'dibel...
# 2  ['kmrn', 'termewek', 'skr', 'lengket', 'lg', '...
# 3  ['intinya', 'kalau', 'kesel', 'dengan', 'att',...
# 4  ['hadewwwww', 'permpuan', 'itu', 'lg', 'sakit'...
#
#                                               step02
# 0  username tolol gak ada hubungan nya keguguran ...
# 1  geblek lo tata cowo bgt dibelain balikan hadew...
# 2  kmrn termewek skr lengket lg duhhh kok labil b...
# 3  intinya kalau kesel dengan att nya gausah ke a...
# 4  hadewwwww permpuan itu lg sakit jiwa knp harus...

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary

factory = StopWordRemoverFactory()

more_stopword = ['sih', 'nya','rt','loh','lah', 'dd', 'mah', 'nye', 'eh', 'ehh', 'ah', 'yang','yg']

# Tambahkan Stopword Baru
data = factory.get_stop_words()+more_stopword

stopwords_sastrawi = factory.create_stop_word_remover()

dictionary = ArrayDictionary(data)
str_stopwords = StopWordRemover(dictionary)

# %%
dataset['finalText_str'] = dataset['step02'].apply(str)

# %%
i=0
final_string = []
s = ""
for sentence in dataset["finalText_str"].values:
    filteredSentence = []
    EachReviewText = ""
    st = str_stopwords.remove(sentence)
    s = (stemmer.stem(st))
    filteredSentence.append(s)

    EachReviewText = ' '.join(filteredSentence)
    final_string.append(EachReviewText)

# %%
dataset.loc[:, ('ProcessedText')] = final_string

# %%
dataset
# Out:
#      Unnamed: 0  Sentiment                             Instagram Comment Text  \
# 0             0          0   <USERNAME> TOLOL!! Gak ada hubungan nya kegug...
# 1             1          0  Geblek lo tata...cowo bgt dibela2in balikan......
# 2             2          0  Kmrn termewek2 skr lengket lg duhhh kok labil ...
# 3             3          0  Intinya kalau kesel dengan ATT nya, gausah ke ...
# 4             4          0  hadewwwww permpuan itu lg!!!!sakit jiwa,knp ha...
# ..          ...        ...                                                ...
# 395         395          1  Bangga sama suami yg selalu ingat istri disela...
# 396         396          1  Apaoun pekerjaannya yg penting halal u tuk men...
# 397         397          1  Gojek itu mayoritas pegangguran yang lama gak ...
# 398         398          1   <USERNAME> aslinya cantik dan ayu loh mbak kr...
# 399         399          1   <USERNAME> suami saya seumuran sama saya mba,...
#
#                                                 step01  \
# 0    username tolol gak ada hubungan nya keguguran ...
# 1    geblek lo tata cowo bgt dibelain balikan hadew...
# 2    kmrn termewek skr lengket lg duhhh kok labil b...
# 3    intinya kalau kesel dengan att nya gausah ke a...
# 4    hadewwwww permpuan itu lg sakit jiwa knp harus...
# ..                                                 ...
# 395  bangga sama suami yg selalu ingat istri disela...
# 396  apaoun pekerjaannya yg penting halal tuk menaf...
# 397  gojek itu mayoritas pegangguran yang lama gak ...
# 398  username aslinya cantik dan ayu loh mbak krn a...
# 399  username suami saya seumuran sama saya mba mal...
#
#                                                 tokens  \
# 0    ['username', 'tolol', 'gak', 'ada', 'hubungan'...
# 1    ['geblek', 'lo', 'tata', 'cowo', 'bgt', 'dibel...
# 2    ['kmrn', 'termewek', 'skr', 'lengket', 'lg', '...
# 3    ['intinya', 'kalau', 'kesel', 'dengan', 'att',...
# 4    ['hadewwwww', 'permpuan', 'itu', 'lg', 'sakit'...
# ..                                                 ...
# 395  ['bangga', 'sama', 'suami', 'yg', 'selalu', 'i...
# 396  ['apaoun', 'pekerjaannya', 'yg', 'penting', 'h...
# 397  ['gojek', 'itu', 'mayoritas', 'pegangguran', '...
# 398  ['username', 'aslinya', 'cantik', 'dan', 'ayu'...
# 399  ['username', 'suami', 'saya', 'seumuran', 'sam...
#
#                                           final_tokens  \
# 0    ['username', 'tolol', 'gak', 'ada', 'hubungan'...
# 1    ['geblek', 'lo', 'tata', 'cowo', 'bgt', 'dibel...
# 2    ['kmrn', 'termewek', 'skr', 'lengket', 'lg', '...
# 3    ['intinya', 'kalau', 'kesel', 'dengan', 'att',...
# 4    ['hadewwwww', 'permpuan', 'itu', 'lg', 'sakit'...
# ..                                                 ...
# 395  ['bangga', 'sama', 'suami', 'yg', 'selalu', 'i...
# 396  ['apaoun', 'pekerjaannya', 'yg', 'penting', 'h...
# 397  ['gojek', 'itu', 'mayoritas', 'pegangguran', '...
# 398  ['username', 'aslinya', 'cantik', 'dan', 'ayu'...
# 399  ['username', 'suami', 'saya', 'seumuran', 'sam...
#
#                                                 step02  \
# 0    username tolol gak ada hubungan nya keguguran ...
# 1    geblek lo tata cowo bgt dibelain balikan hadew...
# 2    kmrn termewek skr lengket lg duhhh kok labil b...
# 3    intinya kalau kesel dengan att nya gausah ke a...
# 4    hadewwwww permpuan itu lg sakit jiwa knp harus...
# ..                                                 ...
# 395  bangga sama suami yg selalu ingat istri disela...
# 396  apaoun pekerjaannya yg penting halal tuk menaf...
# 397  gojek itu mayoritas pegangguran yang lama gak ...
# 398  username aslinya cantik dan ayu loh mbak krn a...
# 399  username suami saya seumuran sama saya mba mal...
#
#                                          finalText_str  \
# 0    username tolol gak ada hubungan nya keguguran ...
# 1    geblek lo tata cowo bgt dibelain balikan hadew...
# 2    kmrn termewek skr lengket lg duhhh kok labil b...
# 3    intinya kalau kesel dengan att nya gausah ke a...
# 4    hadewwwww permpuan itu lg sakit jiwa knp harus...
# ..                                                 ...
# 395  bangga sama suami yg selalu ingat istri disela...
# 396  apaoun pekerjaannya yg penting halal tuk menaf...
# 397  gojek itu mayoritas pegangguran yang lama gak ...
# 398  username aslinya cantik dan ayu loh mbak krn a...
# 399  username suami saya seumuran sama saya mba mal...
#
#                                          ProcessedText
# 0    username tolol gak hubung gugur dgn pake hijab...
# 1    geblek lo tata cowo bgt bain balik hadeww ntar...
# 2    kmrn mewek skr lengket lg duhhh kok labil bgt ...
# 3    inti kalau kesel att gausah anak kasi buat kem...
# 4    hadewwwww permpuan lg sakit jiwa knp dia jd pe...
# ..                                                 ...
# 395  bangga sama suami selalu ingat istri sela wakt...
# 396  apaoun kerja penting halal tuk nafkah keluarga...
# 397  gojek mayoritas pegangguran lama gak kerja tru...
# 398  username asli cantik ayu mbak krn aku temu lan...
# 399  username suami umur sama mba malah tua beberap...
#
# [400 rows x 9 columns]

# %%
dataset.to_csv('clean_dataset_stem.csv',sep=';')
